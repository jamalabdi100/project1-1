# %%
# Dependencies
import pandas as pd
import requests
import json
import os
import csv

# Google developer API key
from api_keys import g_key

# %%
world_happiness = "world happiness data.csv"

world_happiness_df = pd.read_csv(world_happiness, encoding="UTF-8")

 # base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# %%
location_types = "location_types.csv"
location_types_df = pd.read_csv(location_types, encoding="UTF-8")
location_types_df.head()
# Out:
#      location_types   sub_type
# 0           library  Education
# 1            museum  Education
# 2    primary_school  Education
# 3            school  Education
# 4  secondary_school  Education

# %%
health_location_types = location_types_df.loc[location_types_df["sub_type"]
                                               =="Health",:]
health_types_list = []
health_location_types.reset_index(inplace=True)
for i in range(len(health_location_types)):
    health_types_list.append(health_location_types.loc[i,"location_types"])

health_types_list
# Out:
# ['dentist', 'doctor', 'gym', 'hospital', 'pharmacy', 'physiotherapist']

# %%
# geocoordinates
target_country = "united states"

target_type ="hospital"
lat = 4.456
long = 118.3
target_coordinates = f"{lat},{long}"
# target_search = "Chinese"
target_radius = 30000
# "type": "hospital", "key": g_key}
responses = []

# for types in range(len(health_types_list)):
#     params = {"location": target_coordinates,"radius": target_radius,
#               "type": f"{types}", "key": g_key}
#     response = requests.get(base_url, params=params)
#     places_data = response.json()
#     print(json.dumps(places_data, indent=4, sort_keys=True))

params = {"location": "4.456,118.3","key":,"rankby":"distance"}
response = requests.get(base_url, params=params)
places_data = response.json()
print(json.dumps(places_data, indent=4, sort_keys=True))

# # run a request using our params dictionary
# 
# # convert response to json


# # Print the json (pretty printed)
# Out:
# {
#     "html_attributions": [],
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 4.4507453,
#                     "lng": 118.2782246
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 4.452051530291502,
#                         "lng": 118.2795638302915
#                     },
#                     "southwest": {
#                         "lat": 4.449353569708498,
#                         "lng": 118.2768658697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#             "name": "KLK Pinang Mill",
#             "place_id": "ChIJTX0pRhhgFTIRIXwwWuAtUC4",
#             "plus_code": {
#                 "compound_code": "F72H+77 Semporna, Sabah, Malaysia",
#                 "global_code": "6PPWF72H+77"
#             },
#             "rating": 1,
#             "reference": "ChIJTX0pRhhgFTIRIXwwWuAtUC4",
#             "scope": "GOOGLE",
#             "types": [
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "Semporna"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 4.4504307,
#                     "lng": 118.2776777
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 4.451771880291503,
#                         "lng": 118.2791136802915
#                     },
#                     "southwest": {
#                         "lat": 4.449073919708499,
#                         "lng": 118.2764157197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#             "name": "Kilang Kelapa Sawit Pinang",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "place_id": "ChIJ6elWPhhgFTIRtgoQvLFFq0E",
#             "plus_code": {
#                 "compound_code": "F72H+53 Semporna, Sabah, Malaysia",
#                 "global_code": "6PPWF72H+53"
#             },
#             "rating": 3,
#             "reference": "ChIJ6elWPhhgFTIRtgoQvLFFq0E",
#             "scope": "GOOGLE",
#             "types": [
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2,
#             "vicinity": "Semporna"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 4.435336299999999,
#                     "lng": 118.2694279
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 4.436705480291502,
#                         "lng": 118.2707424302915
#                     },
#                     "southwest": {
#                         "lat": 4.434007519708497,
#                         "lng": 118.2680444697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png",
#             "name": "Kantin Humana Pinang",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2322,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101981842704073087798\">Ibrahim Sellimin</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAQhtNh4O3TYLgJbpk4xZQ862GghNQvrRWMWztquFFGCtk0oqdbX6QNQ6MV_X8P_UIlHwCLvIT70gl28I2nOno9LfgeVkS4N5jq3nFV3BCTyiI1YPly_iFhLaULNPKHtmVEhC2T15JRym1yKL8e2Svj4tRGhQlohPCFV4jB0EGBAHtv6nfc_NucQ",
#                     "width": 4128
#                 }
#             ],
#             "place_id": "ChIJU26zw4xhFTIRC5B1Qab7Qco",
#             "plus_code": {
#                 "compound_code": "C7P9+4Q Semporna, Sabah, Malaysia",
#                 "global_code": "6PPWC7P9+4Q"
#             },
#             "rating": 5,
#             "reference": "ChIJU26zw4xhFTIRC5B1Qab7Qco",
#             "scope": "GOOGLE",
#             "types": [
#                 "cafe",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2,
#             "vicinity": "Km 45, Jalan Tawau Semporna, Pekan Semporna, Semporna"
#         },
#         {
#             "business_status": "CLOSED_TEMPORARILY",
#             "geometry": {
#                 "location": {
#                     "lat": 4.4351498,
#                     "lng": 118.2693642
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 4.436513430291502,
#                         "lng": 118.2706671802915
#                     },
#                     "southwest": {
#                         "lat": 4.433815469708497,
#                         "lng": 118.2679692197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#             "name": "Sigalong Golf and Country Club",
#             "permanently_closed": true,
#             "place_id": "ChIJ30EhEkRgFTIRmyb01n7QAkQ",
#             "plus_code": {
#                 "compound_code": "C7P9+3P Semporna, Sabah, Malaysia",
#                 "global_code": "6PPWC7P9+3P"
#             },
#             "rating": 4.6,
#             "reference": "ChIJ30EhEkRgFTIRmyb01n7QAkQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "gym",
#                 "health",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 8,
#             "vicinity": "Semporna"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 4.4348763,
#                     "lng": 118.2692955
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 4.436232580291502,
#                         "lng": 118.2705989802915
#                     },
#                     "southwest": {
#                         "lat": 4.433534619708498,
#                         "lng": 118.2679010197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "Ladang Pinang",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1920,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/113953073876358461403\">Naira Adzkia</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAaEmuu4ks_Z65uIyV26aNQlGRVs3Pe2gkngWWiDjTLpplL7kNbB4TrXAGdyMDEpovEun6lzgW6WXywhmjbmiu6MMFGPxMta54ahCsoKblFdHWpLnT8aGZs2Vjj6q0fqVNEhCQzlWHb89oQ-QZt2mZOusaGhS1F99aGZ5x7FduX9zYhdtrd0-qxQ",
#                     "width": 1080
#                 }
#             ],
#             "place_id": "ChIJb78qbURgFTIRwTjLptqZnFU",
#             "plus_code": {
#                 "compound_code": "C7M9+XP Semporna, Sabah, Malaysia",
#                 "global_code": "6PPWC7M9+XP"
#             },
#             "rating": 4,
#             "reference": "ChIJb78qbURgFTIRwTjLptqZnFU",
#             "scope": "GOOGLE",
#             "types": [
#                 "grocery_or_supermarket",
#                 "food",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 29,
#             "vicinity": "Semporna"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 4.4345849,
#                     "lng": 118.2693575
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 4.435917630291502,
#                         "lng": 118.2706396302915
#                     },
#                     "southwest": {
#                         "lat": 4.433219669708498,
#                         "lng": 118.2679416697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png",
#             "name": "Sk Kalumpang",
#             "place_id": "ChIJmXZ2bkRgFTIRr3PCBfEbaAY",
#             "plus_code": {
#                 "compound_code": "C7M9+RP Semporna, Sabah, Malaysia",
#                 "global_code": "6PPWC7M9+RP"
#             },
#             "reference": "ChIJmXZ2bkRgFTIRr3PCBfEbaAY",
#             "scope": "GOOGLE",
#             "types": [
#                 "school",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Semporna"
#         },
#         {
#             "business_status": "CLOSED_TEMPORARILY",
#             "geometry": {
#                 "location": {
#                     "lat": 4.435173499999999,
#                     "lng": 118.2689518
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 4.436476480291502,
#                         "lng": 118.2704453302915
#                     },
#                     "southwest": {
#                         "lat": 4.433778519708498,
#                         "lng": 118.2677473697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/worship_general-71.png",
#             "name": "Gereja Katolik St Mary's",
#             "permanently_closed": true,
#             "place_id": "ChIJW5kpFERgFTIRBt8owX2zL4k",
#             "plus_code": {
#                 "compound_code": "C7P9+3H Semporna, Sabah, Malaysia",
#                 "global_code": "6PPWC7P9+3H"
#             },
#             "reference": "ChIJW5kpFERgFTIRBt8owX2zL4k",
#             "scope": "GOOGLE",
#             "types": [
#                 "church",
#                 "place_of_worship",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Semporna"
#         },
#         {
#             "business_status": "CLOSED_TEMPORARILY",
#             "geometry": {
#                 "location": {
#                     "lat": 4.4347022,
#                     "lng": 118.2691194
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 4.436055480291502,
#                         "lng": 118.2705054302915
#                     },
#                     "southwest": {
#                         "lat": 4.433357519708498,
#                         "lng": 118.2678074697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "Bengkel Motor Kalumpang",
#             "permanently_closed": true,
#             "place_id": "ChIJoQl3bERgFTIROdW5pOXKI_k",
#             "plus_code": {
#                 "compound_code": "C7M9+VJ Semporna, Sabah, Malaysia",
#                 "global_code": "6PPWC7M9+VJ"
#             },
#             "reference": "ChIJoQl3bERgFTIROdW5pOXKI_k",
#             "scope": "GOOGLE",
#             "types": [
#                 "clothing_store",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "vicinity": "Semporna"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 4.4345952,
#                     "lng": 118.268982
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 4.436042480291502,
#                         "lng": 118.2703405302915
#                     },
#                     "southwest": {
#                         "lat": 4.433344519708498,
#                         "lng": 118.2676425697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "name": "Gerai Makanan, Insyallah Berkah",
#             "photos": [
#                 {
#                     "height": 2204,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101883139710844248868\">RAJIMAN MOHAMAD</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAH4xlBFzJ1UCmkbrQk5f7DA1sKOHu0Wvt0jLehToueSOKdGuBj5Jh-zy16o_dJgAXCq7pnffQjH1G6tt9fBbWVv0o-p7ZQ1tB54YftmSwTsAZFQ0DD7uJ5VzHw_HqAgWqEhAdrqXBOtWFZI5KNUmxhnXhGhSsnBuOnTbi4wxEfEmBRSN2A4HaFA",
#                     "width": 2834
#                 }
#             ],
#             "place_id": "ChIJE6hjaURgFTIRjQVYdi0BAb8",
#             "plus_code": {
#                 "compound_code": "C7M9+RH Semporna, Sabah, Malaysia",
#                 "global_code": "6PPWC7M9+RH"
#             },
#             "rating": 4.7,
#             "reference": "ChIJE6hjaURgFTIRjQVYdi0BAb8",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 3,
#             "vicinity": "Semporna"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 4.4345895,
#                     "lng": 118.2688036
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 4.436048130291502,
#                         "lng": 118.2701632302915
#                     },
#                     "southwest": {
#                         "lat": 4.433350169708497,
#                         "lng": 118.2674652697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "Sama Jaya Super Store",
#             "place_id": "ChIJSxLxaURgFTIRilwNX1buzSg",
#             "plus_code": {
#                 "compound_code": "C7M9+RG Semporna, Sabah, Malaysia",
#                 "global_code": "6PPWC7M9+RG"
#             },
#             "reference": "ChIJSxLxaURgFTIRilwNX1buzSg",
#             "scope": "GOOGLE",
#             "types": [
#                 "grocery_or_supermarket",
#                 "food",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "vicinity": "Semporna"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 4.429192599999999,
#                     "lng": 118.261651
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 4.430630980291502,
#                         "lng": 118.2631168302915
#                     },
#                     "southwest": {
#                         "lat": 4.427933019708497,
#                         "lng": 118.2604188697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/civic_building-71.png",
#             "name": "HRC JPVS Kalumpang Semporna",
#             "photos": [
#                 {
#                     "height": 3120,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/113618185106059846572\">Shah LDU</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAQZMEYyAgvOhlMXsdaNQvNgQoGYbyDPux72fQ3olOUCIl0FhBkeQK0HLz3AP0ku7PhG8QTx56lG8VwZH1wpbgne-yENL_Tg6wi562bAWbVqCJPIq9Y2GauXAdD1iqurPBEhA5BtWKPngGTl8WiONjcc89GhQDag-D1gObicynt8Cdl5-mBOswaQ",
#                     "width": 4160
#                 }
#             ],
#             "place_id": "ChIJUYaE_lBgFTIRLY8HCiE0pgY",
#             "plus_code": {
#                 "compound_code": "C7H6+MM Semporna, Sabah, Malaysia",
#                 "global_code": "6PPWC7H6+MM"
#             },
#             "rating": 5,
#             "reference": "ChIJUYaE_lBgFTIRLY8HCiE0pgY",
#             "scope": "GOOGLE",
#             "types": [
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "Semporna"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 4.450538799999999,
#                     "lng": 118.2457189
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 4.451909830291503,
#                         "lng": 118.2470890302915
#                     },
#                     "southwest": {
#                         "lat": 4.449211869708498,
#                         "lng": 118.2443910697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#             "name": "Bridge Sg Kalumpang",
#             "place_id": "ChIJu44CWVhhFTIRqbhbZJxO1rw",
#             "plus_code": {
#                 "global_code": "6PPWF62W+67"
#             },
#             "rating": 5,
#             "reference": "ChIJu44CWVhhFTIRqbhbZJxO1rw",
#             "scope": "GOOGLE",
#             "types": [
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "SA51, Semporna"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 4.4534042,
#                     "lng": 118.2432375
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 4.454441430291503,
#                         "lng": 118.2444800302915
#                     },
#                     "southwest": {
#                         "lat": 4.451743469708498,
#                         "lng": 118.2417820697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/civic_building-71.png",
#             "name": "Loji Rawatan Air Baru Semporna",
#             "place_id": "ChIJa67r-dBhFTIRkeUVe9Fd_rI",
#             "plus_code": {
#                 "global_code": "6PPWF63V+97"
#             },
#             "reference": "ChIJa67r-dBhFTIRkeUVe9Fd_rI",
#             "scope": "GOOGLE",
#             "types": [
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "SA51, Semporna"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 4.497849,
#                     "lng": 118.3390899
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 4.499203180291502,
#                         "lng": 118.3404422802915
#                     },
#                     "southwest": {
#                         "lat": 4.496505219708498,
#                         "lng": 118.3377443197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#             "name": "Pejabat Sipit Division Ladang Segaria",
#             "place_id": "ChIJ-QQNeJXhPzIRn7kvFJY-RVU",
#             "plus_code": {
#                 "compound_code": "F8XQ+4J Semporna, Sabah, Malaysia",
#                 "global_code": "6PPWF8XQ+4J"
#             },
#             "reference": "ChIJ-QQNeJXhPzIRn7kvFJY-RVU",
#             "scope": "GOOGLE",
#             "types": [
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Semporna"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 4.4148127,
#                     "lng": 118.3407619
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 4.416095680291502,
#                         "lng": 118.3420779302915
#                     },
#                     "southwest": {
#                         "lat": 4.413397719708497,
#                         "lng": 118.3393799697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/civic_building-71.png",
#             "name": "PEKAH SDN BHD",
#             "place_id": "ChIJ5zI7AlReFTIRriLoaoWacAU",
#             "plus_code": {
#                 "compound_code": "C87R+W8 Semporna, Sabah, Malaysia",
#                 "global_code": "6PPWC87R+W8"
#             },
#             "rating": 5,
#             "reference": "ChIJ5zI7AlReFTIRriLoaoWacAU",
#             "scope": "GOOGLE",
#             "types": [
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "Semporna"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 4.419077,
#                     "lng": 118.3461948
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 4.420425980291502,
#                         "lng": 118.3475437802915
#                     },
#                     "southwest": {
#                         "lat": 4.417728019708497,
#                         "lng": 118.3448458197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#             "name": "Borneo Semporna Proboscis River Cruise",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/109603871100680593467\">Tai Yong Seng</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA3PLC-CroFLAAUvcHfD-8gfyPtj-01eCA4XhemoJ0MruD339b7c9vlmFi4tbezvc6-XXlnFJWm4eDhZ648C48HbLO78gwhY9izZReVKI_vK2-ngERl3XmjxHfsyPhngzpEhA81pWggS95Eetnrm8wJV0FGhTZzxoODN0RURM1uE6WThbUdRAo2g",
#                     "width": 4000
#                 }
#             ],
#             "place_id": "ChIJq6qqqqpfFTIRIPNzgwxxh2g",
#             "plus_code": {
#                 "compound_code": "C89W+JF Semporna, Sabah, Malaysia",
#                 "global_code": "6PPWC89W+JF"
#             },
#             "rating": 3.7,
#             "reference": "ChIJq6qqqqpfFTIRIPNzgwxxh2g",
#             "scope": "GOOGLE",
#             "types": [
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 3,
#             "vicinity": "Sungai Buaya, Kampung Tunggulangan, 91308, Semporna, Sabah, Malaysia, Semporna"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 4.398172,
#                     "lng": 118.3134852
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 4.399383880291502,
#                         "lng": 118.3148581802915
#                     },
#                     "southwest": {
#                         "lat": 4.396685919708498,
#                         "lng": 118.3121602197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "success merchant sdn bhd",
#             "photos": [
#                 {
#                     "height": 3264,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100685211931929349648\">Pinadis Jamesday</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAeDtO-16Fx3JFhrHGaGV-xgfq4TVzCh_4GhrbSrQd3mmc7A9IZTEBc-x57EAk62dSwoK0JLZEjUwADH_cM02Yy26iHFPW0Q_uddKtBGYWx7bqNid7KSzVi7KHaSzbTZVjEhA2xxE3AgOdltJxFB3E33drGhQ3diqultK4IIMrIBsrpBezzApFiw",
#                     "width": 1836
#                 }
#             ],
#             "place_id": "ChIJgek9pWBfFTIRbRkmVaCGjfs",
#             "plus_code": {
#                 "compound_code": "98X7+79 Semporna, Sabah, Malaysia",
#                 "global_code": "6PPW98X7+79"
#             },
#             "rating": 5,
#             "reference": "ChIJgek9pWBfFTIRbRkmVaCGjfs",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "Sg.Pinang, Miles 41 Off Semporna Tawau Road, 91308, Semporna"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 4.479700500000001,
#                     "lng": 118.2436309
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 4.481139880291503,
#                         "lng": 118.2449876302915
#                     },
#                     "southwest": {
#                         "lat": 4.478441919708498,
#                         "lng": 118.2422896697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#             "name": "Sg. Kalumpang Raw Water Intaake Plant",
#             "place_id": "ChIJCXMwtp_fPzIRpHXREGjr80Q",
#             "plus_code": {
#                 "compound_code": "F6HV+VF Kunak, Sabah, Malaysia",
#                 "global_code": "6PPWF6HV+VF"
#             },
#             "reference": "ChIJCXMwtp_fPzIRpHXREGjr80Q",
#             "scope": "GOOGLE",
#             "types": [
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Semporna"
#         }
#     ],
#     "status": "OK"
# }

# %%
# print the response url, avoid doing for public github repos in order to avoid exposing key
#print(response.url)

# %%
# convert response to json
places_data = response.json()

# Print the json (pretty printed)
print(json.dumps(places_data, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "results": [],
#     "status": "INVALID_REQUEST"
# }

# %%
# Print the name and address of the first restaurant that appears
print(places_data["results"][0]["name"])
print(places_data["results"][0]["vicinity"])
# Out:
# -------------------------------------------------------------------------
# IndexError                              Traceback (most recent call last)
# <ipython-input-8-6be944f96bd0> in <module>
#       1 # Print the name and address of the first restaurant that appears
# ----> 2 print(places_data["results"][0]["name"])
#       3 print(places_data["results"][0]["vicinity"])
#
# IndexError: list index out of range
